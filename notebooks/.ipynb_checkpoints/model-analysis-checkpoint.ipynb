# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %cd '../src'
# Out:
# /media/apfriend/sabrent/ucsd/classes/cse151b/kaggle/src

# %%
import os
import sys
import re
import shutil
import pandas as pd
import random
import warnings
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pickle
from glob import glob
import matplotlib.pyplot as plt
import random
import multiprocessing
from tqdm.auto import tqdm
import seaborn as sns
from IPython.display import display

#####LOCAL SCRIPTS FROM src#####
import utility
import load_data as load_data
import models.lstm as lstm
import models.linear as linear
import models.physics as physics
from ArgoverseDataset import ArgoverseDataset
import run_model as run_model

# %%
device='cuda:0'
test_path='../data/test-data'
val_path='../data/validation-data/new_val_in'
train_path='../data/train-data'
model_path='/home/apfriend/ucsd/CURRENT/cse151b/kaggle/trained-models/final-models'

# %%
help('a'.replace)
# Out:
# Help on built-in function replace:
#
# replace(old, new, count=-1, /) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %%
test_inp, test_out=load_data.get_test_data(test_path, 3000)
test_inp, test_out=test_inp.to(device), test_out.to(device)
test_pred=physics.avg_velocity_model(test_inp)

pos_idx=torch.tensor([0,1]).to(device)
test_out_pos=torch.index_select(test_out, 3, pos_idx)
print('RMSE: %f'%utility.rmse(test_pred, test_out_pos).detach().cpu().numpy())

# utility.visualize_trajectory(test_inp, test_out_pos, test_pred)
# Out:
# RMSE: 27.795698

# %%
models=os.listdir(model_path)
replace_str=r'0\.\d{2}0000'
new_str=r''

for model in models:
    model_name=model.split('.')[0]
    if model_name in model_names.keys():
        model_name_new=model_names[model_name]#+'.pth'
        model_name_new=model_name_new.replace('0.','').replace('0000','')
        model_name_new+='.pth'
        
        src_fn=os.path.join(model_path, model)
        dst_fn=os.path.join(model_path, model_name_new)
        os.rename(src_fn,dst_fn)

# %%
os.listdir(model_path)
# Out:
# ['final-multilayer-linear-dropout25-batchsz128-epoch1.pth',
#  'final-multilayer-linear-dropout25-batchsz128-epoch5.pth',
#  'final-multilayer-linear-dropout25-batchsz16-epoch1.pth',
#  'final-multilayer-linear-dropout25-batchsz16-epoch5.pth',
#  'final-multilayer-linear-dropout25-batchsz32-epoch1.pth',
#  'final-multilayer-linear-dropout25-batchsz32-epoch5.pth',
#  'final-multilayer-linear-dropout25-batchsz64-epoch1.pth',
#  'final-multilayer-linear-dropout25-batchsz64-epoch5.pth',
#  'final-multilayer-linear-dropout50-batchsz128-epoch1.pth',
#  'final-multilayer-linear-dropout50-batchsz128-epoch10.pth',
#  'final-multilayer-linear-dropout50-batchsz128-epoch5.pth',
#  'final-multilayer-linear-dropout50-batchsz16-epoch1.pth',
#  'final-multilayer-linear-dropout50-batchsz16-epoch5.pth',
#  'final-multilayer-linear-dropout50-batchsz32-epoch1.pth',
#  'final-multilayer-linear-dropout50-batchsz32-epoch5.pth',
#  'final-multilayer-linear-dropout50-batchsz64-epoch1.pth',
#  'final-multilayer-linear-dropout50-batchsz64-epoch5.pth',
#  'final-multilayer-linear-dropout75-batchsz128-epoch1.pth',
#  'final-multilayer-linear-dropout75-batchsz128-epoch10.pth',
#  'final-multilayer-linear-dropout75-batchsz128-epoch5.pth',
#  'final-multilayer-linear-dropout75-batchsz16-epoch5.pth',
#  'final-multilayer-linear-dropout75-batchsz32-epoch1.pth',
#  'final-multilayer-linear-dropout75-batchsz32-epoch5.pth',
#  'final-multilayer-linear-dropout75-batchsz64-epoch1.pth',
#  'final-multilayer-linear-dropout75-batchsz64-epoch5.pth',
#  'final-multilayer-linear2-dropout25-batchsz128-epoch1.pth',
#  'final-multilayer-linear2-dropout25-batchsz128-epoch5.pth',
#  'final-multilayer-linear2-dropout25-batchsz16-epoch1.pth',
#  'final-multilayer-linear2-dropout25-batchsz16-epoch5.pth',
#  'final-multilayer-linear2-dropout25-batchsz32-epoch1.pth',
#  'final-multilayer-linear2-dropout25-batchsz32-epoch5.pth',
#  'final-multilayer-linear2-dropout25-batchsz64-epoch1.pth',
#  'final-multilayer-linear2-dropout25-batchsz64-epoch5.pth',
#  'final-multilayer-linear2-dropout50-batchsz128-epoch1.pth',
#  'final-multilayer-linear2-dropout50-batchsz128-epoch10.pth',
#  'final-multilayer-linear2-dropout50-batchsz128-epoch5.pth',
#  'final-multilayer-linear2-dropout50-batchsz16-epoch1.pth',
#  'final-multilayer-linear2-dropout50-batchsz16-epoch5.pth',
#  'final-multilayer-linear2-dropout50-batchsz32-epoch1.pth',
#  'final-multilayer-linear2-dropout50-batchsz32-epoch5.pth',
#  'final-multilayer-linear-dropout75-batchsz16-epoch1.pth',
#  'final-multilayer-linear2-dropout50-batchsz64-epoch1.pth',
#  'final-simple-linear-dropout50-batchsz128-epoch5.pth',
#  'final-multilayer-linear2-dropout50-batchsz64-epoch5.pth',
#  'final-multilayer-linear2-dropout75-batchsz128-epoch1.pth',
#  'final-multilayer-linear2-dropout75-batchsz128-epoch10.pth',
#  'final-multilayer-linear2-dropout75-batchsz128-epoch5.pth',
#  'final-multilayer-linear2-dropout75-batchsz16-epoch1.pth',
#  'final-multilayer-linear2-dropout75-batchsz16-epoch5.pth',
#  'final-multilayer-linear2-dropout75-batchsz32-epoch1.pth',
#  'final-multilayer-linear2-dropout75-batchsz32-epoch5.pth',
#  'final-multilayer-linear2-dropout75-batchsz64-epoch1.pth',
#  'final-multilayer-linear2-dropout75-batchsz64-epoch5.pth',
#  'final-simple-linear-dropout25-batchsz128-epoch1.pth',
#  'final-simple-linear-dropout25-batchsz128-epoch10.pth',
#  'final-simple-linear-dropout25-batchsz128-epoch5.pth',
#  'final-simple-linear-dropout25-batchsz16-epoch1.pth',
#  'final-simple-linear-dropout25-batchsz16-epoch5.pth',
#  'final-simple-linear-dropout25-batchsz32-epoch1.pth',
#  'final-simple-linear-dropout25-batchsz32-epoch5.pth',
#  'final-simple-linear-dropout25-batchsz64-epoch1.pth',
#  'final-simple-linear-dropout25-batchsz64-epoch5.pth',
#  'final-simple-linear-dropout50-batchsz128-epoch1.pth',
#  'final-simple-linear-dropout50-batchsz128-epoch10.pth',
#  'final-simple-linear-dropout50-batchsz16-epoch1.pth',
#  'final-simple-linear-dropout50-batchsz16-epoch5.pth',
#  'final-simple-linear-dropout50-batchsz32-epoch1.pth',
#  'final-simple-linear-dropout50-batchsz32-epoch5.pth',
#  'final-simple-linear-dropout50-batchsz64-epoch1.pth',
#  'final-simple-linear-dropout50-batchsz64-epoch5.pth',
#  'final-simple-linear-dropout75-batchsz128-epoch1.pth',
#  'final-simple-linear-dropout75-batchsz128-epoch10.pth',
#  'final-simple-linear-dropout75-batchsz128-epoch5.pth',
#  'final-simple-linear-dropout75-batchsz16-epoch1.pth',
#  'final-simple-linear-dropout75-batchsz16-epoch5.pth',
#  'final-simple-linear-dropout75-batchsz32-epoch1.pth',
#  'final-simple-linear-dropout75-batchsz32-epoch5.pth',
#  'final-simple-linear-dropout75-batchsz64-epoch1.pth',
#  'final-simple-linear-dropout75-batchsz64-epoch5.pth']

# %%
model_df=utility.compare_rmse(
    src=model_path,
    data_path=test_path
)
model_df
# Out:
# 100%|██████████| 80/80 [01:05<00:00,  1.22it/s]
#                 model_name       rmse  dropout  batch_size  num_epochs
# 0   Average Velocity Model  27.092701      NaN         128         NaN
# 1        multilayer linear  114.92213     0.25         128         1.0
# 2        multilayer linear  42.824436     0.25         128         5.0
# 3        multilayer linear  143.51817     0.25          16         1.0
# 4        multilayer linear  120.88324     0.25          16         5.0
# ..                     ...        ...      ...         ...         ...
# 75           simple linear  239.69218     0.75          16         5.0
# 76           simple linear   520.2131     0.75          32         1.0
# 77           simple linear  251.21112     0.75          32         5.0
# 78           simple linear   545.5287     0.75          64         1.0
# 79           simple linear  241.20534     0.75          64         5.0
#
# [80 rows x 5 columns]

# %%
utility.visualize_model_loss(model_df, 'simple linear', 'epoch')
# model_df.dtypes
# Out:
#        model_name       rmse  dropout  batch_size  num_epochs
# 43  simple linear  213.39001     0.50         128         5.0
# 54  simple linear   509.8615     0.25         128         1.0
# 55  simple linear  149.15347     0.25         128        10.0
# 56  simple linear  218.46867     0.25         128         5.0
# 57  simple linear   497.5271     0.25          16         1.0
# 58  simple linear  215.73743     0.25          16         5.0
# 59  simple linear  527.48926     0.25          32         1.0
# 60  simple linear  227.39052     0.25          32         5.0
# 61  simple linear   521.7568     0.25          64         1.0
# 62  simple linear   219.2367     0.25          64         5.0
# 63  simple linear  495.76596     0.50         128         1.0
# 64  simple linear  175.68028     0.50         128        10.0
# 65  simple linear   461.2078     0.50          16         1.0
# 66  simple linear  273.96512     0.50          16         5.0
# 67  simple linear  552.12775     0.50          32         1.0
# 68  simple linear  272.56555     0.50          32         5.0
# 69  simple linear   545.7005     0.50          64         1.0
# 70  simple linear  208.85489     0.50          64         5.0
# 71  simple linear  524.11926     0.75         128         1.0
# 72  simple linear  192.23265     0.75         128        10.0
# 73  simple linear  240.01218     0.75         128         5.0
# 74  simple linear  443.85623     0.75          16         1.0
# 75  simple linear  239.69218     0.75          16         5.0
# 76  simple linear   520.2131     0.75          32         1.0
# 77  simple linear  251.21112     0.75          32         5.0
# 78  simple linear   545.5287     0.75          64         1.0
# 79  simple linear  241.20534     0.75          64         5.0
#             dropout  batch_size
# num_epochs
# 1.0             0.5          60
# 5.0             0.5          60
# 10.0            0.5         128

# %%
# simple_linear_df=model_df.loc[model_df.model_name=='simple linear']
# multilayer1_df=model_df.loc[model_df.model_name=='multilayer linear']
# multilayer2_df=model_df.loc[model_df.model_name=='multilayer linear2']

min_rmse=list(model_df.groupby(by='model_name').rmse.min().values)
model_df.loc[model_df.rmse.isin(min_rmse)]
# min_rmse
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: unhashable type: 'numpy.ndarray'
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-211-e2958162b9ba> in <module>
#       4
#       5 min_rmse=list(model_df.groupby(by='model_name').rmse.min().values)
# ----> 6 model_df.loc[model_df['rmse'].isin(min_rmse)]
#       7 # min_rmse
#
# ~/anaconda3/envs/cse151b/lib/python3.8/site-packages/pandas/core/series.py in isin(self, values)
#    4663         dtype: bool
#    4664         """
# -> 4665         result = algorithms.isin(self._values, values)
#    4666         return self._constructor(result, index=self.index).__finalize__(
#    4667             self, method="isin"
#
# ~/anaconda3/envs/cse151b/lib/python3.8/site-packages/pandas/core/algorithms.py in isin(comps, values)
#     491         f = getattr(htable, f"ismember_{name}")
#     492
# --> 493     return f(comps, values)
#     494
#     495
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.ismember_object()
#
# SystemError: <built-in method view of numpy.ndarray object at 0x7f7bf50f8c30> returned a result with an error set

# %%
test_fn='/home/apfriend/ucsd/CURRENT/cse151b/kaggle/trained-models/final-models/final-multilayer-linear-dropout25-batchsz128-epoch1.pth'

type(torch.load(test_fn))
# Out:
# collections.OrderedDict

# %%
submit_dir='/home/apfriend/ucsd/CURRENT/cse151b/kaggle/data/submit-data'
physics_submit_fn='physics-model-submit.csv'

submit_df=run_model.submit_model(
    model=physics.avg_velocity_model,
    data_path=val_path,
    batch_size=128,
    save_path=submit_dir,
    save_fn=physics_submit_fn,
    physics_model=True
)

submit_df
# Out:
# 100%|██████████| 25/25 [00:06<00:00,  4.10it/s]
#          ID           v1           v2           v3           v4           v5  \
# 0     10002  1722.862793   344.908600  1731.862915   353.518494  1740.863037
# 1     10015   724.523743  1226.880127   723.511047  1223.799072   722.498291
# 2     10019   575.700317  1244.186401   577.596252  1243.683350   579.492249
# 3     10028  1696.872559   320.736633  1702.991699   326.379883  1709.110718
# 4      1003  2111.357910   667.496155  2098.635742   656.805664  2085.913818
# ...     ...          ...          ...          ...          ...          ...
# 3195   9897   258.019531   804.328186   259.845276   803.041077   261.671021
# 3196     99   588.072449  1148.757568   588.309082  1143.011353   588.545776
# 3197   9905  1754.132568   447.194000  1752.528442   450.522766  1750.924438
# 3198   9910   574.143311  1287.442139   573.582275  1285.806885   573.021179
# 3199   9918   585.531189  1155.604736   586.412781  1145.471558   587.294312
#
#                v6           v7           v8           v9  ...          v51  \
# 0      362.128357  1749.863159   370.738220  1758.863403  ...  1947.866211
# 1     1220.718018   721.485535  1217.636963   720.472778  ...   699.205261
# 2     1243.180176   581.388245  1242.677124   583.284180  ...   623.099731
# 3      332.023102  1715.229736   337.666321  1721.348877  ...  1849.849121
# 4      646.115234  2073.191895   635.424744  2060.469727  ...  1793.307739
# ...           ...          ...          ...          ...  ...          ...
# 3195   801.753967   263.496765   800.466858   265.322510  ...   303.663147
# 3196  1137.265259   588.782410  1131.519165   589.019104  ...   593.989075
# 3197   453.851501  1749.320312   457.180267  1747.716309  ...  1714.030884
# 3198  1284.171631   572.460083  1282.536255   571.898987  ...   560.116333
# 3199  1135.338257   588.175903  1125.204956   589.057434  ...   607.570129
#
#               v52          v53          v54          v55          v56  \
# 0      560.155396  1956.866333   568.765320  1965.866455   577.375183
# 1     1149.854004   698.192505  1146.772949   697.179810  1143.691895
# 2     1231.609375   624.995667  1231.106323   626.891663  1230.603271
# 3      461.817322  1855.968140   467.460571  1862.087280   473.103821
# 4      400.234283  1780.585815   389.543823  1767.863770   378.853333
# ...           ...          ...          ...          ...          ...
# 3195   772.150391   305.488892   770.863281   307.314636   769.576172
# 3196  1005.104370   594.225708   999.358215   594.462402   993.612122
# 3197   530.412720  1712.426880   533.741455  1710.822754   537.070251
# 3198  1246.560303   559.555237  1244.925049   558.994202  1243.289795
# 3199   902.273193   608.451721   892.140015   609.333252   882.006714
#
#               v57          v58          v59          v60
# 0     1974.866699   585.985046  1983.866699   594.594910
# 1      696.167053  1140.610840   695.154297  1137.529785
# 2      628.787598  1230.100098   630.683594  1229.597046
# 3     1868.206299   478.747009  1874.325317   484.390259
# 4     1755.141846   368.162842  1742.419800   357.472382
# ...           ...          ...          ...          ...
# 3195   309.140350   768.289062   310.966095   767.001953
# 3196   594.699036   987.865967   594.935730   982.119873
# 3197  1709.218750   540.398987  1707.614624   543.727722
# 3198   558.433105  1241.654541   557.872009  1240.019287
# 3199   610.214844   871.873413   611.096375   861.740173
#
# [3200 rows x 61 columns]

# %%
models=[linear.simple_model, linear.multilayer_model, linear.multilayer_model2]
model_names=['simple-linear','multilayer-linear','multilayer-linear2']

model_dict=dict(zip(models, model_names))

batch_szs=[128,64,32,16]
epochs=[1,5,10,20,30]
dropout_list=[0.5,0.75,0.25]

model_names={}

idx=1

for epoch in epochs:
    for batch_sz in batch_szs:
        for dropout in dropout_list:
            for model in models:
                name='final-'+model_dict[model]+'-dropout%f-batchsz%i-epoch%i'%(dropout,batch_sz,epoch)
                old_name='model-test-%i'%idx
                model_names[old_name]=name
                idx+=1
model_names
# Out:
# {'model-test-1': 'final-simple-linear-dropout0.500000-batchsz128-epoch1',
#  'model-test-2': 'final-multilayer-linear-dropout0.500000-batchsz128-epoch1',
#  'model-test-3': 'final-multilayer-linear2-dropout0.500000-batchsz128-epoch1',
#  'model-test-4': 'final-simple-linear-dropout0.750000-batchsz128-epoch1',
#  'model-test-5': 'final-multilayer-linear-dropout0.750000-batchsz128-epoch1',
#  'model-test-6': 'final-multilayer-linear2-dropout0.750000-batchsz128-epoch1',
#  'model-test-7': 'final-simple-linear-dropout0.250000-batchsz128-epoch1',
#  'model-test-8': 'final-multilayer-linear-dropout0.250000-batchsz128-epoch1',
#  'model-test-9': 'final-multilayer-linear2-dropout0.250000-batchsz128-epoch1',
#  'model-test-10': 'final-simple-linear-dropout0.500000-batchsz64-epoch1',
#  'model-test-11': 'final-multilayer-linear-dropout0.500000-batchsz64-epoch1',
#  'model-test-12': 'final-multilayer-linear2-dropout0.500000-batchsz64-epoch1',
#  'model-test-13': 'final-simple-linear-dropout0.750000-batchsz64-epoch1',
#  'model-test-14': 'final-multilayer-linear-dropout0.750000-batchsz64-epoch1',
#  'model-test-15': 'final-multilayer-linear2-dropout0.750000-batchsz64-epoch1',
#  'model-test-16': 'final-simple-linear-dropout0.250000-batchsz64-epoch1',
#  'model-test-17': 'final-multilayer-linear-dropout0.250000-batchsz64-epoch1',
#  'model-test-18': 'final-multilayer-linear2-dropout0.250000-batchsz64-epoch1',
#  'model-test-19': 'final-simple-linear-dropout0.500000-batchsz32-epoch1',
#  'model-test-20': 'final-multilayer-linear-dropout0.500000-batchsz32-epoch1',
#  'model-test-21': 'final-multilayer-linear2-dropout0.500000-batchsz32-epoch1',
#  'model-test-22': 'final-simple-linear-dropout0.750000-batchsz32-epoch1',
#  'model-test-23': 'final-multilayer-linear-dropout0.750000-batchsz32-epoch1',
#  'model-test-24': 'final-multilayer-linear2-dropout0.750000-batchsz32-epoch1',
#  'model-test-25': 'final-simple-linear-dropout0.250000-batchsz32-epoch1',
#  'model-test-26': 'final-multilayer-linear-dropout0.250000-batchsz32-epoch1',
#  'model-test-27': 'final-multilayer-linear2-dropout0.250000-batchsz32-epoch1',
#  'model-test-28': 'final-simple-linear-dropout0.500000-batchsz16-epoch1',
#  'model-test-29': 'final-multilayer-linear-dropout0.500000-batchsz16-epoch1',
#  'model-test-30': 'final-multilayer-linear2-dropout0.500000-batchsz16-epoch1',
#  'model-test-31': 'final-simple-linear-dropout0.750000-batchsz16-epoch1',
#  'model-test-32': 'final-multilayer-linear-dropout0.750000-batchsz16-epoch1',
#  'model-test-33': 'final-multilayer-linear2-dropout0.750000-batchsz16-epoch1',
#  'model-test-34': 'final-simple-linear-dropout0.250000-batchsz16-epoch1',
#  'model-test-35': 'final-multilayer-linear-dropout0.250000-batchsz16-epoch1',
#  'model-test-36': 'final-multilayer-linear2-dropout0.250000-batchsz16-epoch1',
#  'model-test-37': 'final-simple-linear-dropout0.500000-batchsz128-epoch5',
#  'model-test-38': 'final-multilayer-linear-dropout0.500000-batchsz128-epoch5',
#  'model-test-39': 'final-multilayer-linear2-dropout0.500000-batchsz128-epoch5',
#  'model-test-40': 'final-simple-linear-dropout0.750000-batchsz128-epoch5',
#  'model-test-41': 'final-multilayer-linear-dropout0.750000-batchsz128-epoch5',
#  'model-test-42': 'final-multilayer-linear2-dropout0.750000-batchsz128-epoch5',
#  'model-test-43': 'final-simple-linear-dropout0.250000-batchsz128-epoch5',
#  'model-test-44': 'final-multilayer-linear-dropout0.250000-batchsz128-epoch5',
#  'model-test-45': 'final-multilayer-linear2-dropout0.250000-batchsz128-epoch5',
#  'model-test-46': 'final-simple-linear-dropout0.500000-batchsz64-epoch5',
#  'model-test-47': 'final-multilayer-linear-dropout0.500000-batchsz64-epoch5',
#  'model-test-48': 'final-multilayer-linear2-dropout0.500000-batchsz64-epoch5',
#  'model-test-49': 'final-simple-linear-dropout0.750000-batchsz64-epoch5',
#  'model-test-50': 'final-multilayer-linear-dropout0.750000-batchsz64-epoch5',
#  'model-test-51': 'final-multilayer-linear2-dropout0.750000-batchsz64-epoch5',
#  'model-test-52': 'final-simple-linear-dropout0.250000-batchsz64-epoch5',
#  'model-test-53': 'final-multilayer-linear-dropout0.250000-batchsz64-epoch5',
#  'model-test-54': 'final-multilayer-linear2-dropout0.250000-batchsz64-epoch5',
#  'model-test-55': 'final-simple-linear-dropout0.500000-batchsz32-epoch5',
#  'model-test-56': 'final-multilayer-linear-dropout0.500000-batchsz32-epoch5',
#  'model-test-57': 'final-multilayer-linear2-dropout0.500000-batchsz32-epoch5',
#  'model-test-58': 'final-simple-linear-dropout0.750000-batchsz32-epoch5',
#  'model-test-59': 'final-multilayer-linear-dropout0.750000-batchsz32-epoch5',
#  'model-test-60': 'final-multilayer-linear2-dropout0.750000-batchsz32-epoch5',
#  'model-test-61': 'final-simple-linear-dropout0.250000-batchsz32-epoch5',
#  'model-test-62': 'final-multilayer-linear-dropout0.250000-batchsz32-epoch5',
#  'model-test-63': 'final-multilayer-linear2-dropout0.250000-batchsz32-epoch5',
#  'model-test-64': 'final-simple-linear-dropout0.500000-batchsz16-epoch5',
#  'model-test-65': 'final-multilayer-linear-dropout0.500000-batchsz16-epoch5',
#  'model-test-66': 'final-multilayer-linear2-dropout0.500000-batchsz16-epoch5',
#  'model-test-67': 'final-simple-linear-dropout0.750000-batchsz16-epoch5',
#  'model-test-68': 'final-multilayer-linear-dropout0.750000-batchsz16-epoch5',
#  'model-test-69': 'final-multilayer-linear2-dropout0.750000-batchsz16-epoch5',
#  'model-test-70': 'final-simple-linear-dropout0.250000-batchsz16-epoch5',
#  'model-test-71': 'final-multilayer-linear-dropout0.250000-batchsz16-epoch5',
#  'model-test-72': 'final-multilayer-linear2-dropout0.250000-batchsz16-epoch5',
#  'model-test-73': 'final-simple-linear-dropout0.500000-batchsz128-epoch10',
#  'model-test-74': 'final-multilayer-linear-dropout0.500000-batchsz128-epoch10',
#  'model-test-75': 'final-multilayer-linear2-dropout0.500000-batchsz128-epoch10',
#  'model-test-76': 'final-simple-linear-dropout0.750000-batchsz128-epoch10',
#  'model-test-77': 'final-multilayer-linear-dropout0.750000-batchsz128-epoch10',
#  'model-test-78': 'final-multilayer-linear2-dropout0.750000-batchsz128-epoch10',
#  'model-test-79': 'final-simple-linear-dropout0.250000-batchsz128-epoch10',
#  'model-test-80': 'final-multilayer-linear-dropout0.250000-batchsz128-epoch10',
#  'model-test-81': 'final-multilayer-linear2-dropout0.250000-batchsz128-epoch10',
#  'model-test-82': 'final-simple-linear-dropout0.500000-batchsz64-epoch10',
#  'model-test-83': 'final-multilayer-linear-dropout0.500000-batchsz64-epoch10',
#  'model-test-84': 'final-multilayer-linear2-dropout0.500000-batchsz64-epoch10',
#  'model-test-85': 'final-simple-linear-dropout0.750000-batchsz64-epoch10',
#  'model-test-86': 'final-multilayer-linear-dropout0.750000-batchsz64-epoch10',
#  'model-test-87': 'final-multilayer-linear2-dropout0.750000-batchsz64-epoch10',
#  'model-test-88': 'final-simple-linear-dropout0.250000-batchsz64-epoch10',
#  'model-test-89': 'final-multilayer-linear-dropout0.250000-batchsz64-epoch10',
#  'model-test-90': 'final-multilayer-linear2-dropout0.250000-batchsz64-epoch10',
#  'model-test-91': 'final-simple-linear-dropout0.500000-batchsz32-epoch10',
#  'model-test-92': 'final-multilayer-linear-dropout0.500000-batchsz32-epoch10',
#  'model-test-93': 'final-multilayer-linear2-dropout0.500000-batchsz32-epoch10',
#  'model-test-94': 'final-simple-linear-dropout0.750000-batchsz32-epoch10',
#  'model-test-95': 'final-multilayer-linear-dropout0.750000-batchsz32-epoch10',
#  'model-test-96': 'final-multilayer-linear2-dropout0.750000-batchsz32-epoch10',
#  'model-test-97': 'final-simple-linear-dropout0.250000-batchsz32-epoch10',
#  'model-test-98': 'final-multilayer-linear-dropout0.250000-batchsz32-epoch10',
#  'model-test-99': 'final-multilayer-linear2-dropout0.250000-batchsz32-epoch10',
#  'model-test-100': 'final-simple-linear-dropout0.500000-batchsz16-epoch10',
#  'model-test-101': 'final-multilayer-linear-dropout0.500000-batchsz16-epoch10',
#  'model-test-102': 'final-multilayer-linear2-dropout0.500000-batchsz16-epoch10',
#  'model-test-103': 'final-simple-linear-dropout0.750000-batchsz16-epoch10',
#  'model-test-104': 'final-multilayer-linear-dropout0.750000-batchsz16-epoch10',
#  'model-test-105': 'final-multilayer-linear2-dropout0.750000-batchsz16-epoch10',
#  'model-test-106': 'final-simple-linear-dropout0.250000-batchsz16-epoch10',
#  'model-test-107': 'final-multilayer-linear-dropout0.250000-batchsz16-epoch10',
#  'model-test-108': 'final-multilayer-linear2-dropout0.250000-batchsz16-epoch10',
#  'model-test-109': 'final-simple-linear-dropout0.500000-batchsz128-epoch20',
#  'model-test-110': 'final-multilayer-linear-dropout0.500000-batchsz128-epoch20',
#  'model-test-111': 'final-multilayer-linear2-dropout0.500000-batchsz128-epoch20',
#  'model-test-112': 'final-simple-linear-dropout0.750000-batchsz128-epoch20',
#  'model-test-113': 'final-multilayer-linear-dropout0.750000-batchsz128-epoch20',
#  'model-test-114': 'final-multilayer-linear2-dropout0.750000-batchsz128-epoch20',
#  'model-test-115': 'final-simple-linear-dropout0.250000-batchsz128-epoch20',
#  'model-test-116': 'final-multilayer-linear-dropout0.250000-batchsz128-epoch20',
#  'model-test-117': 'final-multilayer-linear2-dropout0.250000-batchsz128-epoch20',
#  'model-test-118': 'final-simple-linear-dropout0.500000-batchsz64-epoch20',
#  'model-test-119': 'final-multilayer-linear-dropout0.500000-batchsz64-epoch20',
#  'model-test-120': 'final-multilayer-linear2-dropout0.500000-batchsz64-epoch20',
#  'model-test-121': 'final-simple-linear-dropout0.750000-batchsz64-epoch20',
#  'model-test-122': 'final-multilayer-linear-dropout0.750000-batchsz64-epoch20',
#  'model-test-123': 'final-multilayer-linear2-dropout0.750000-batchsz64-epoch20',
#  'model-test-124': 'final-simple-linear-dropout0.250000-batchsz64-epoch20',
#  'model-test-125': 'final-multilayer-linear-dropout0.250000-batchsz64-epoch20',
#  'model-test-126': 'final-multilayer-linear2-dropout0.250000-batchsz64-epoch20',
#  'model-test-127': 'final-simple-linear-dropout0.500000-batchsz32-epoch20',
#  'model-test-128': 'final-multilayer-linear-dropout0.500000-batchsz32-epoch20',
#  'model-test-129': 'final-multilayer-linear2-dropout0.500000-batchsz32-epoch20',
#  'model-test-130': 'final-simple-linear-dropout0.750000-batchsz32-epoch20',
#  'model-test-131': 'final-multilayer-linear-dropout0.750000-batchsz32-epoch20',
#  'model-test-132': 'final-multilayer-linear2-dropout0.750000-batchsz32-epoch20',
#  'model-test-133': 'final-simple-linear-dropout0.250000-batchsz32-epoch20',
#  'model-test-134': 'final-multilayer-linear-dropout0.250000-batchsz32-epoch20',
#  'model-test-135': 'final-multilayer-linear2-dropout0.250000-batchsz32-epoch20',
#  'model-test-136': 'final-simple-linear-dropout0.500000-batchsz16-epoch20',
#  'model-test-137': 'final-multilayer-linear-dropout0.500000-batchsz16-epoch20',
#  'model-test-138': 'final-multilayer-linear2-dropout0.500000-batchsz16-epoch20',
#  'model-test-139': 'final-simple-linear-dropout0.750000-batchsz16-epoch20',
#  'model-test-140': 'final-multilayer-linear-dropout0.750000-batchsz16-epoch20',
#  'model-test-141': 'final-multilayer-linear2-dropout0.750000-batchsz16-epoch20',
#  'model-test-142': 'final-simple-linear-dropout0.250000-batchsz16-epoch20',
#  'model-test-143': 'final-multilayer-linear-dropout0.250000-batchsz16-epoch20',
#  'model-test-144': 'final-multilayer-linear2-dropout0.250000-batchsz16-epoch20',
#  'model-test-145': 'final-simple-linear-dropout0.500000-batchsz128-epoch30',
#  'model-test-146': 'final-multilayer-linear-dropout0.500000-batchsz128-epoch30',
#  'model-test-147': 'final-multilayer-linear2-dropout0.500000-batchsz128-epoch30',
#  'model-test-148': 'final-simple-linear-dropout0.750000-batchsz128-epoch30',
#  'model-test-149': 'final-multilayer-linear-dropout0.750000-batchsz128-epoch30',
#  'model-test-150': 'final-multilayer-linear2-dropout0.750000-batchsz128-epoch30',
#  'model-test-151': 'final-simple-linear-dropout0.250000-batchsz128-epoch30',
#  'model-test-152': 'final-multilayer-linear-dropout0.250000-batchsz128-epoch30',
#  'model-test-153': 'final-multilayer-linear2-dropout0.250000-batchsz128-epoch30',
#  'model-test-154': 'final-simple-linear-dropout0.500000-batchsz64-epoch30',
#  'model-test-155': 'final-multilayer-linear-dropout0.500000-batchsz64-epoch30',
#  'model-test-156': 'final-multilayer-linear2-dropout0.500000-batchsz64-epoch30',
#  'model-test-157': 'final-simple-linear-dropout0.750000-batchsz64-epoch30',
#  'model-test-158': 'final-multilayer-linear-dropout0.750000-batchsz64-epoch30',
#  'model-test-159': 'final-multilayer-linear2-dropout0.750000-batchsz64-epoch30',
#  'model-test-160': 'final-simple-linear-dropout0.250000-batchsz64-epoch30',
#  'model-test-161': 'final-multilayer-linear-dropout0.250000-batchsz64-epoch30',
#  'model-test-162': 'final-multilayer-linear2-dropout0.250000-batchsz64-epoch30',
#  'model-test-163': 'final-simple-linear-dropout0.500000-batchsz32-epoch30',
#  'model-test-164': 'final-multilayer-linear-dropout0.500000-batchsz32-epoch30',
#  'model-test-165': 'final-multilayer-linear2-dropout0.500000-batchsz32-epoch30',
#  'model-test-166': 'final-simple-linear-dropout0.750000-batchsz32-epoch30',
#  'model-test-167': 'final-multilayer-linear-dropout0.750000-batchsz32-epoch30',
#  'model-test-168': 'final-multilayer-linear2-dropout0.750000-batchsz32-epoch30',
#  'model-test-169': 'final-simple-linear-dropout0.250000-batchsz32-epoch30',
#  'model-test-170': 'final-multilayer-linear-dropout0.250000-batchsz32-epoch30',
#  'model-test-171': 'final-multilayer-linear2-dropout0.250000-batchsz32-epoch30',
#  'model-test-172': 'final-simple-linear-dropout0.500000-batchsz16-epoch30',
#  'model-test-173': 'final-multilayer-linear-dropout0.500000-batchsz16-epoch30',
#  'model-test-174': 'final-multilayer-linear2-dropout0.500000-batchsz16-epoch30',
#  'model-test-175': 'final-simple-linear-dropout0.750000-batchsz16-epoch30',
#  'model-test-176': 'final-multilayer-linear-dropout0.750000-batchsz16-epoch30',
#  'model-test-177': 'final-multilayer-linear2-dropout0.750000-batchsz16-epoch30',
#  'model-test-178': 'final-simple-linear-dropout0.250000-batchsz16-epoch30',
#  'model-test-179': 'final-multilayer-linear-dropout0.250000-batchsz16-epoch30',
#  'model-test-180': 'final-multilayer-linear2-dropout0.250000-batchsz16-epoch30'}
